# %% [markdown]
# <a href="https://colab.research.google.com/github/poornimakr2001/Data_Visualisation/blob/main/boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data creation (you can replace this with your own dataset)
data = {'Category': ['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
        'Value': [10, 12, 14, 15, 18, 21, 13, 16, 19]}

# Create a DataFrame
df = pd.DataFrame(data)

# Plotting the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Value', data=df)

# Adding title and labels
plt.title('Boxplot of Values by Category')
plt.xlabel('Category')
plt.ylabel('Value')

# Display the plot
plt.show()
